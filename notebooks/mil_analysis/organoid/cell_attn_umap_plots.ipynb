# %%
import scanpy as sc

# %%
adata = sc.read('../../../pipeline/data/multigrate_mil/organoid_atlas_subset/330de7f8e8_adata_both.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 444132 × 10
# ...

# %%
sc.pl.umap(adata, color=['cell_attn', 'cell_line', 'cell_type', 'disease', 'assay_sc', 'assay_differentiation', 'assay_type_differentiation'], ncols=1, frameon=False)
# Out:
# /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/seacells/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/seacells/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /lustre/groups/ml01/workspace/anastasia.litinetskaya/mambaforge/envs/seacells/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# ...
