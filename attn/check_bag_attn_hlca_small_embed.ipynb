# %%
import scanpy as sc
import numpy as np

# %%
adata = sc.read('../run_baselines/data/multigrate_mil/41301bf6a3/0/checkpoints/train_anndata.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 438582 × 30
# ...

# %%
# query = sc.read('../run_baselines/data/multigrate_mil/41301bf6a3/0/checkpoints/epoch=49-step=37200_query_anndata.h5ad')
# query

# %%
idx = adata.obs['sample'].sort_values().index
adata = adata[idx].copy()

# %%
sample_adatas = []
for sample in np.unique(adata.obs['sample']):
    sample_adatas.append(adata[adata.obs['sample'] == sample])

# %%
bag_adatas = []
for sample_adata in sample_adatas:
    print('--------')
    print(len(sample_adata))
    for i in range(0, len(sample_adata), 128):
        if i+128 < len(sample_adata):
            idx = list(sample_adata.obs_names)[i: i+128]
            bag_adatas.append(sample_adata[idx])
        else:
            idx = list(sample_adata.obs_names)[-i:]
            bag_adatas.append(sample_adata[idx])

# %%
len(bag_adatas)
# Out:
# 3482

# %%
for tmp in bag_adatas:
    print(len(tmp))
    print(np.sum(tmp.obs['cell_attn']))
# Out:
# 128
# 0.97050667
# 128
# 1.0105424
# 128
# 0.9966216
# 128
# 1.0035529
# 128
# 0.96683383
# 128
# 1.0442739
# 128
# 1.0045271
# 128
# 1.0181503
# 128
# 0.9760876
# 128
# 0.99912184
# 128
# 1.0064386
# 128
# 0.98942566
# 128
# 0.9835801
# 128
# 1.022438
# 128
# 0.9937898
# 128
# 0.99622667
# 128
# 1.039195
# 2176
# 17.0255
# 128
# 1.0006274
# 128
# 0.99756455
# 128
# 0.9889233
# 128
# 1.0441464
# 128
# 0.9662565
# 128
# 0.9915135
# 128
# 1.0150495
# 128
# 1.008352
# 128
# 0.98928535
# 128
# 0.9878197
# 128
# 0.9844318
# 128
# 0.9785302
# 128
# 1.0271506
# 128
# 0.9943908
# 128
# 0.986542
# 128
# 1.034936
# 128
# 0.9957228
# 128
# 0.97755134
# 128
# 1.03094
# 128
# 1.0001343
# 128
# 0.98586977
# 128
# 0.9982351
# 128
# 1.0631609
# 128
# 0.96577394
# 128
# 0.9715903
# 128
# 1.0272908
# 128
# 0.9861071
# 3456
# 27.003408
# 128
# 1.0115385
# 128
# 0.99660015
# 128
# 0.9946835
# 128
# 0.97723985
# 128
# 1.0031433
# 128
# 1.0123951
# 128
# 0.97141564
# 128
# 1.0296531
# 128
# 0.99807686
# ...

# %%
for tmp in q_bag_anndatas:
    print(np.sum(tmp.obs['cell_attn']))
# Out:
# 4.0
# 3.5078125
# 4.0
# 4.0
# 3.6171875
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 0.23437497
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 3.9999998
# 0.609375
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 3.015625
# 3.9999998
# 0.24218751
# 0.0078125
# 3.8906248
# 4.0
# 4.0
# 4.0
# 3.1328123
# 4.0
# 4.0
# 4.0
# 1.1796874
# 4.0
# 4.0
# 4.0
# 4.0
# 0.375
# 4.0
# 4.0
# 4.0
# 1.3359375
# 4.0
# 2.6562502
# 4.0
# 4.0
# 4.0
# 4.0
# 2.796875
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 3.9999995
# 4.0
# 3.7500002
# 4.0
# 4.0
# 0.6171875
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 2.7187502
# 4.0
# 4.0
# 4.0
# 1.21875
# 4.0
# 4.0
# 3.4453123
# 4.0
# 4.0
# 3.359375
# 4.0
# 4.0
# 4.0
# 4.0
# 0.51562506
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 1.234375
# 4.0
# 4.0
# 4.0
# 0.093749985
# 4.0
# 2.75
# 4.0
# 4.0
# 4.0
# 4.0
# 4.0
# 0.671875
# 0.625
# 3.9999995
