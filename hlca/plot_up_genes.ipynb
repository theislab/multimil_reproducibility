# %%
x=1

# %%
import scanpy as sc
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# Some plotting aesthetics
# %matplotlib inline

# sns.set_style('ticks')
matplotlib.rcParams['figure.figsize'] = [4, 4]
matplotlib.rcParams['figure.dpi'] = 100
matplotlib.rcParams['figure.dpi'] = 100
sc.set_figure_params(vector_friendly=True)

# %%
adata = sc.read('../pipeline_mil/data/analysis/hlca_healthy_ipf_embed_balanced/adata_final.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 450214 × 30
# ...

# %%
hlca = sc.read('../../snakemake/hlca/5fold/hlca_hyperparam/data/pp/hlca_hvg_pearson.h5ad')
hlca
# Out:
# AnnData object with n_obs × n_vars = 2149684 × 2000
# ...

# %%
genes = [
     'ENSG00000026751',
     'ENSG00000102962',
     'ENSG00000110092',
     'ENSG00000125735',
     'ENSG00000143320',
     'ENSG00000151789',
     'ENSG00000159674',
     'ENSG00000164266',
     'ENSG00000166165',
     'ENSG00000262406',
]

# %%
macrophages = hlca[adata[adata.obs['celltype'] == 'Macrophages'].obs_names].copy()
macrophages.obs['cell_attn'] = adata[adata.obs['celltype'] == 'Macrophages'].obs['cell_attn']
macrophages.obsm['X_umap'] = adata[adata.obs['celltype'] == 'Macrophages'].obsm['X_umap']
macrophages
# Out:
# AnnData object with n_obs × n_vars = 158750 × 2000
# ...

# %%
sc.pp.normalize_total(macrophages, target_sum=1e4)
sc.pp.log1p(macrophages)

# %%
for g in genes:
    sc.pl.umap(
        macrophages,
        color=g,
        ncols=1,
        frameon=False,
        vmax='p99',
        save=f'_{g}_expression.svg'
    )
# Out:
# WARNING: saving figure to file figures/umap_ENSG00000026751_expression.svg
# WARNING: saving figure to file figures/umap_ENSG00000102962_expression.svg
# WARNING: saving figure to file figures/umap_ENSG00000110092_expression.svg
# WARNING: saving figure to file figures/umap_ENSG00000125735_expression.svg
# WARNING: saving figure to file figures/umap_ENSG00000143320_expression.svg
# WARNING: saving figure to file figures/umap_ENSG00000151789_expression.svg
# WARNING: saving figure to file figures/umap_ENSG00000159674_expression.svg
# WARNING: saving figure to file figures/umap_ENSG00000164266_expression.svg
# WARNING: saving figure to file figures/umap_ENSG00000166165_expression.svg
# WARNING: saving figure to file figures/umap_ENSG00000262406_expression.svg
