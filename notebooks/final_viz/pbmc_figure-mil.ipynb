# %%
x=2

# %%
import scanpy as sc
import anndata as ad
import numpy as np
import pandas as pd
import decoupler as dc

from sklearn.model_selection import LeaveOneOut
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
sc.set_figure_params(vector_friendly=True, figsize=(4,4))

# %%
adata = sc.read('../../pipeline/data/multigrate_mil/pbmc_mtg_final1/old_0b64090fba_adata_both.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 256051 × 2188
#     obs: 'sample_id', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'full_clustering', 'initial_clustering', 'Resample', 'Collection_Day', 'Sex', 'Age_interval', 'Swab_result', 'Status', 'Smoker', 'Status_on_day_collection', 'Status_on_day_collection_summary', 'Days_from_onset', 'Site', 'time_after_LPS', 'Worst_Clinical_Status', 'Outcome', 'patient_id', 'split0', 'split1', 'split2', 'split3', 'split4', 'group', 'size_factors', '_scvi_batch', 'cell_attn_0', 'cell_attn_1', 'cell_attn_2', 'cell_attn_3', 'cell_attn_4', 'cell_attn'
#     var: 'modality'
#     uns: 'Site_colors', 'Status_on_day_collection_summary_colors', '_scvi_manager_uuid', '_scvi_uuid', 'full_clustering_colors', 'initial_clustering_colors', 'modality_lengths', 'neighbors', 'patient_id_colors', 'umap'
#     obsm: 'X_umap', '_scvi_extra_categorical_covs', 'latent', 'latent_0', 'latent_1', 'latent_2', 'latent_3', 'latent_4'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(
    adata,
    color=['cell_attn'],
    frameon=False,
    ncols=1,
    #palette=colors,
    color_map="GnBu",
    title='',
    legend_loc=None,
    vmax='p99',
    #save='_pbmc_cell_attn.svg'
)

# %%
sc.pl.umap(
    adata,
    color=['initial_clustering'],
    ncols=1,
    frameon=False, 
    #save='_pbmc_celltypes.svg'
)

# %%
sc.pl.umap(
    adata,
    color=['Status_on_day_collection_summary'],
    palette=['#EAE280', '#E59A88', '#B62A6F'],
    ncols=1,
    frameon=False,
    #save='_pbmc_cond.svg'
)

# %%
dfs = []
for cond in np.unique(adata.obs['Status_on_day_collection_summary']):
    adata_tmp = adata[adata.obs['Status_on_day_collection_summary'] == cond].copy()
    threshold_idx = int(len(adata_tmp) * 0.9)
    threshold_value = sorted(adata_tmp.obs['cell_attn'])[threshold_idx]
    adata_tmp.obs['group'] = 'all cells'
    adata_tmp.obs.loc[adata_tmp.obs['cell_attn'] >= threshold_value, 'group'] = 'top 10% cells'
    adata.obs[f'top_cells_{cond}'] = False
    adata.obs.loc[adata_tmp[adata_tmp.obs['group'] == 'top 10% cells'].obs_names, f'top_cells_{cond}'] = True
    adata.obs[f'top_cells_{cond}'] = adata.obs[f'top_cells_{cond}'].astype('category')
    dfs.append(adata_tmp[adata_tmp.obs['group'] == 'top 10% cells'].obs[['initial_clustering', 'Status_on_day_collection_summary']])

# %%
sc.pl.umap(
    adata,
    color=[f'top_cells_Healthy'],
    groups=[True],
    palette=['#EAE280'],
    frameon=False,
    #save='_pbmc_top_healthy.svg'
)
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.

# %%
sc.pl.umap(adata, color=[f'top_cells_Mild'], groups=[True], palette=['#E59A88'], frameon=False, 
           #save='_pbmc_top_mild.svg'
          )
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.

# %%
sc.pl.umap(adata, color=[f'top_cells_Severe'], groups=[True], palette=['#B62A6F'], frameon=False, 
           #save='_pbmc_top_severe.svg'
          )
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 1, categories length: 2. Some categories will have the same color.

# %%
ct_df = adata.obs[['Status_on_day_collection_summary', 'initial_clustering']]
ct_df_group = ct_df.groupby('Status_on_day_collection_summary').value_counts(normalize=True).mul(100)
ct_df_group = ct_df_group.unstack().reindex(['Healthy', 'Mild', 'Severe']).T

# %%
ct_df_group['Mild - Healthy'] = (ct_df_group['Mild'] - ct_df_group['Healthy']) / ct_df_group['Healthy']
ct_df_group['Severe - Healthy'] = (ct_df_group['Severe'] - ct_df_group['Healthy']) / ct_df_group['Healthy']
ct_df_group['Severe - Mild'] = (ct_df_group['Severe'] - ct_df_group['Mild']) / ct_df_group['Healthy']
ct_df_group
# Out:
# Status_on_day_collection_summary    Healthy       Mild     Severe  \
# initial_clustering
# B_cell                             7.798926  10.613397  11.691050
# CD4                               29.130556  24.407099  20.337316
# CD8                               19.369532  14.057488  14.178752
# CD14                              10.626655  18.917111  17.498243
# CD16                               3.571760   4.007579   1.963841
# DCs                                2.179536   1.390764   0.727017
# HSC                                0.148394   0.242733   1.020891
# Lymph_prolif                       0.290605   1.330080   1.308375
# MAIT                               2.075454   1.202521   0.512362
# Mono_prolif                        0.004122   0.021053   0.196767
# NK_16hi                           13.025691  12.726169  17.185204
# NK_56hi                            2.289801   2.184601   1.673801
# Plasmablast                        0.118509   1.239675   3.569923
# Platelets                          2.210451   1.815547   3.819076
# RBC                                0.336978   0.375246   0.208267
# Treg                               2.411402   2.128872   1.810516
# gdT                                3.701605   2.147448   1.010669
# pDC                                0.710024   1.192614   1.287932
#
# Status_on_day_collection_summary  Mild - Healthy  Severe - Healthy  \
# initial_clustering
# B_cell                                  0.360879          0.499059
# CD4                                    -0.162148         -0.301856
# CD8                                    -0.274247         -0.267987
# CD14                                    0.780157          0.646637
# CD16                                    0.122018         -0.450176
# DCs                                    -0.361899         -0.666435
# HSC                                     0.635737          5.879597
# Lymph_prolif                            3.576939          3.502250
# MAIT                                   -0.420598         -0.753133
# Mono_prolif                             4.107506         46.735278
# NK_16hi                                -0.022995          0.319332
# NK_56hi                                -0.045943         -0.269019
# Plasmablast                             9.460589         29.123629
# Platelets                              -0.178653          0.727736
# RBC                                     0.113563         -0.381957
# Treg                                   -0.117164         -0.249185
# gdT                                    -0.419860         -0.726965
# pDC                                     0.679682          0.813928
#
# Status_on_day_collection_summary  Severe - Mild
# initial_clustering
# B_cell                                 0.138180
# CD4                                   -0.139708
# CD8                                    0.006261
# CD14                                  -0.133520
# CD16                                  -0.572194
# DCs                                   -0.304536
# HSC                                    5.243860
# Lymph_prolif                          -0.074689
# MAIT                                  -0.332534
# Mono_prolif                           42.627772
# NK_16hi                                0.342326
# NK_56hi                               -0.223076
# Plasmablast                           19.663039
# Platelets                              0.906389
# RBC                                   -0.495520
# Treg                                  -0.132021
# gdT                                   -0.307104
# pDC                                    0.134246

# %%
adata.obs['initial_clustering'].value_counts()
# Out:
# CD4             63893
# CD8             41244
# CD14            39282
# NK_16hi         36366
# B_cell          25288
# CD16             8239
# Platelets        6600
# gdT              6117
# Treg             5476
# NK_56hi          5296
# Plasmablast      3910
# DCs              3807
# MAIT             3386
# pDC              2660
# Lymph_prolif     2380
# HSC              1139
# RBC               793
# Mono_prolif       175
# Name: initial_clustering, dtype: int64

# %%
ct_df_group = ct_df_group.drop(['RBC', 'Mono_prolif'])

# %%
ct_df_group
# Out:
# Status_on_day_collection_summary    Healthy       Mild     Severe  \
# initial_clustering
# B_cell                             7.798926  10.613397  11.691050
# CD4                               29.130556  24.407099  20.337316
# CD8                               19.369532  14.057488  14.178752
# CD14                              10.626655  18.917111  17.498243
# CD16                               3.571760   4.007579   1.963841
# DCs                                2.179536   1.390764   0.727017
# HSC                                0.148394   0.242733   1.020891
# Lymph_prolif                       0.290605   1.330080   1.308375
# MAIT                               2.075454   1.202521   0.512362
# NK_16hi                           13.025691  12.726169  17.185204
# NK_56hi                            2.289801   2.184601   1.673801
# Plasmablast                        0.118509   1.239675   3.569923
# Platelets                          2.210451   1.815547   3.819076
# Treg                               2.411402   2.128872   1.810516
# gdT                                3.701605   2.147448   1.010669
# pDC                                0.710024   1.192614   1.287932
#
# Status_on_day_collection_summary  Mild - Healthy  Severe - Healthy  \
# initial_clustering
# B_cell                                  0.360879          0.499059
# CD4                                    -0.162148         -0.301856
# CD8                                    -0.274247         -0.267987
# CD14                                    0.780157          0.646637
# CD16                                    0.122018         -0.450176
# DCs                                    -0.361899         -0.666435
# HSC                                     0.635737          5.879597
# Lymph_prolif                            3.576939          3.502250
# MAIT                                   -0.420598         -0.753133
# NK_16hi                                -0.022995          0.319332
# NK_56hi                                -0.045943         -0.269019
# Plasmablast                             9.460589         29.123629
# Platelets                              -0.178653          0.727736
# Treg                                   -0.117164         -0.249185
# gdT                                    -0.419860         -0.726965
# pDC                                     0.679682          0.813928
#
# Status_on_day_collection_summary  Severe - Mild
# initial_clustering
# B_cell                                 0.138180
# CD4                                   -0.139708
# CD8                                    0.006261
# CD14                                  -0.133520
# CD16                                  -0.572194
# DCs                                   -0.304536
# HSC                                    5.243860
# Lymph_prolif                          -0.074689
# MAIT                                  -0.332534
# NK_16hi                                0.342326
# NK_56hi                               -0.223076
# Plasmablast                           19.663039
# Platelets                              0.906389
# Treg                                  -0.132021
# gdT                                   -0.307104
# pDC                                    0.134246

# %%
ct_df_group.sort_values('Mild - Healthy')
# Out:
# Status_on_day_collection_summary    Healthy       Mild     Severe  \
# initial_clustering
# MAIT                               2.075454   1.202521   0.512362
# gdT                                3.701605   2.147448   1.010669
# DCs                                2.179536   1.390764   0.727017
# CD8                               19.369532  14.057488  14.178752
# Platelets                          2.210451   1.815547   3.819076
# CD4                               29.130556  24.407099  20.337316
# Treg                               2.411402   2.128872   1.810516
# NK_56hi                            2.289801   2.184601   1.673801
# NK_16hi                           13.025691  12.726169  17.185204
# CD16                               3.571760   4.007579   1.963841
# B_cell                             7.798926  10.613397  11.691050
# HSC                                0.148394   0.242733   1.020891
# pDC                                0.710024   1.192614   1.287932
# CD14                              10.626655  18.917111  17.498243
# Lymph_prolif                       0.290605   1.330080   1.308375
# Plasmablast                        0.118509   1.239675   3.569923
#
# Status_on_day_collection_summary  Mild - Healthy  Severe - Healthy  \
# initial_clustering
# MAIT                                   -0.420598         -0.753133
# gdT                                    -0.419860         -0.726965
# DCs                                    -0.361899         -0.666435
# CD8                                    -0.274247         -0.267987
# Platelets                              -0.178653          0.727736
# CD4                                    -0.162148         -0.301856
# Treg                                   -0.117164         -0.249185
# NK_56hi                                -0.045943         -0.269019
# NK_16hi                                -0.022995          0.319332
# CD16                                    0.122018         -0.450176
# B_cell                                  0.360879          0.499059
# HSC                                     0.635737          5.879597
# pDC                                     0.679682          0.813928
# CD14                                    0.780157          0.646637
# Lymph_prolif                            3.576939          3.502250
# Plasmablast                             9.460589         29.123629
#
# Status_on_day_collection_summary  Severe - Mild
# initial_clustering
# MAIT                                  -0.332534
# gdT                                   -0.307104
# DCs                                   -0.304536
# CD8                                    0.006261
# Platelets                              0.906389
# CD4                                   -0.139708
# Treg                                  -0.132021
# NK_56hi                               -0.223076
# NK_16hi                                0.342326
# CD16                                  -0.572194
# B_cell                                 0.138180
# HSC                                    5.243860
# pDC                                    0.134246
# CD14                                  -0.133520
# Lymph_prolif                          -0.074689
# Plasmablast                           19.663039

# %%
ct_df_group.sort_values('Severe - Healthy')
# Out:
# Status_on_day_collection_summary    Healthy       Mild     Severe  \
# initial_clustering
# MAIT                               2.075454   1.202521   0.512362
# gdT                                3.701605   2.147448   1.010669
# DCs                                2.179536   1.390764   0.727017
# CD16                               3.571760   4.007579   1.963841
# CD4                               29.130556  24.407099  20.337316
# NK_56hi                            2.289801   2.184601   1.673801
# CD8                               19.369532  14.057488  14.178752
# Treg                               2.411402   2.128872   1.810516
# NK_16hi                           13.025691  12.726169  17.185204
# B_cell                             7.798926  10.613397  11.691050
# CD14                              10.626655  18.917111  17.498243
# Platelets                          2.210451   1.815547   3.819076
# pDC                                0.710024   1.192614   1.287932
# Lymph_prolif                       0.290605   1.330080   1.308375
# HSC                                0.148394   0.242733   1.020891
# Plasmablast                        0.118509   1.239675   3.569923
#
# Status_on_day_collection_summary  Mild - Healthy  Severe - Healthy  \
# initial_clustering
# MAIT                                   -0.420598         -0.753133
# gdT                                    -0.419860         -0.726965
# DCs                                    -0.361899         -0.666435
# CD16                                    0.122018         -0.450176
# CD4                                    -0.162148         -0.301856
# NK_56hi                                -0.045943         -0.269019
# CD8                                    -0.274247         -0.267987
# Treg                                   -0.117164         -0.249185
# NK_16hi                                -0.022995          0.319332
# B_cell                                  0.360879          0.499059
# CD14                                    0.780157          0.646637
# Platelets                              -0.178653          0.727736
# pDC                                     0.679682          0.813928
# Lymph_prolif                            3.576939          3.502250
# HSC                                     0.635737          5.879597
# Plasmablast                             9.460589         29.123629
#
# Status_on_day_collection_summary  Severe - Mild
# initial_clustering
# MAIT                                  -0.332534
# gdT                                   -0.307104
# DCs                                   -0.304536
# CD16                                  -0.572194
# CD4                                   -0.139708
# NK_56hi                               -0.223076
# CD8                                    0.006261
# Treg                                  -0.132021
# NK_16hi                                0.342326
# B_cell                                 0.138180
# CD14                                  -0.133520
# Platelets                              0.906389
# pDC                                    0.134246
# Lymph_prolif                          -0.074689
# HSC                                    5.243860
# Plasmablast                           19.663039

# %%
df = ct_df_group.loc[['Plasmablast', 'HSC', 'Lymph_prolif', 'pDC', 'Platelets']]

# %%
sc.set_figure_params(vector_friendly=True, figsize=(6,4))

# %%
fig, ax = plt.subplots(1, 1)
ax.grid(zorder=0)
df[['Healthy', 'Mild', 'Severe']].plot.bar(color=['#EAE280', '#E59A88', '#B62A6F'], rot=45, legend=False, ax=ax, zorder=3, width=0.8)
plt.title('Cell types with highest fold change in composition\n')
plt.xlabel('')
plt.ylabel('Proportion in cell type composition')
#plt.savefig('figures/bar_pbmc_proportions.svg', bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Proportion in cell type composition')

# %%
df = pd.read_csv('/lustre/groups/ml01/projects/2022_multigrate_anastasia.litinetskaya/multimil_reproducibility/pipeline/data/reports/best.tsv', sep='\t', index_col=None)
task = 'pbmc_mtg_final1'

# %%
runs = {}
yerr = {}
df_task = df[df['task'] == task]
for method in np.unique(df_task['method']):
    runs[method] = eval(df_task.loc[df_task['method'] == method, 'accuracies'].values[0])
    yerr[method] = np.array(runs[method]).std()

df_tmp = df_task[['method', 'accuracy']]
df_tmp.index = df_tmp['method']
df_tmp = df_tmp[['accuracy']].sort_values('accuracy', ascending=False)
df_tmp = df_tmp.T

yerr_sorted = [yerr[method] for method in df_tmp.columns]

# %%
df_tmp.columns
# Out:
# Index(['multigrate_mil_reg', 'multigrate_mil', 'ct_pb_mr', 'ct_pb_nn', 'pb_nn',
#        'ct_pb_rf', 'freq_rf', 'pb_rf', 'gex_rf', 'gex_nn', 'freq_nn',
#        'freq_mr'],
#       dtype='object', name='method')

# %%
df_tmp = df_tmp[['multigrate_mil_reg', 'multigrate_mil', 'ct_pb_mr', 'ct_pb_nn', 'ct_pb_rf', 'pb_nn', 'pb_rf', 'freq_rf', 'freq_nn', 'freq_mr', 'gex_rf', 'gex_nn']]

# %%
df_tmp.columns
# Out:
# Index(['multigrate_mil_reg', 'multigrate_mil', 'ct_pb_mr', 'ct_pb_nn',
#        'ct_pb_rf', 'pb_nn', 'pb_rf', 'freq_rf', 'freq_nn', 'freq_mr', 'gex_rf',
#        'gex_nn'],
#       dtype='object', name='method')

# %%
df_tmp = df_tmp.rename(columns={
    'multigrate_mil_reg': 'Regression',
    'multigrate_mil': 'Classification',
    'ct_pb_mr': 'MR', 
    'ct_pb_nn': 'NN',
    'ct_pb_rf': 'RF', 
    'pb_nn': 'NN',
    'pb_rf': 'RF', 
    'freq_rf': 'RF', 
    'freq_nn': 'NN',
    'freq_mr': 'MR', 
    'gex_rf': 'RF', 
    'gex_nn': 'NN',
})

# %%
ax = df_tmp.T.plot(kind='bar', zorder=3, figsize=(8, 4), color=["#00a8cc"], rot=45, yerr=yerr_sorted, width=0.8)
ax.get_legend().remove()
ax.grid(zorder=0, linewidth=0.5)
plt.xlabel('Method')
plt.ylabel('Accuracy')
plt.title('')
plt.savefig('figures/pbmc_accuracy.svg', bbox_inches='tight')

# %% [markdown]
# ### patient repr

# %%
adata.obs
# Out:
#                                   sample_id  n_genes  n_genes_by_counts  \
# covid_index
# AAACCTGAGACCACGA-newcastle65    newcastle65     1351               1351
# AAACCTGAGATGTCGG-newcastle65    newcastle65     1921               1921
# AAACCTGAGGCGATAC-newcastle65    newcastle65     1056               1056
# AAACCTGAGTACACCT-newcastle65    newcastle65     2140               2140
# AAACCTGAGTGAATTG-newcastle65    newcastle65     1620               1620
# ...                                     ...      ...                ...
# BGCV15_TTTGGTTGTTGGGACA-1     BGCV15_CV0176     1631               1631
# BGCV15_TTTGGTTTCAAGATCC-1     BGCV15_CV0944     2503               2503
# BGCV15_TTTGTCAAGGCGATAC-1     BGCV15_CV0176     2401               2401
# BGCV15_TTTGTCACAAGCCATT-1     BGCV15_CV0944     1973               1973
# BGCV15_TTTGTCATCGAATGGG-1     BGCV15_CV0176     1798               1798
#
#                               total_counts  total_counts_mt  pct_counts_mt  \
# covid_index
# AAACCTGAGACCACGA-newcastle65        4278.0            178.0       4.160823
# AAACCTGAGATGTCGG-newcastle65        4740.0            127.0       2.679325
# AAACCTGAGGCGATAC-newcastle65        2875.0            198.0       6.886957
# AAACCTGAGTACACCT-newcastle65        5260.0            316.0       6.007605
# AAACCTGAGTGAATTG-newcastle65        4043.0            232.0       5.738313
# ...                                    ...              ...            ...
# BGCV15_TTTGGTTGTTGGGACA-1           5325.0            184.0       3.455399
# BGCV15_TTTGGTTTCAAGATCC-1           6681.0            264.0       3.951504
# BGCV15_TTTGTCAAGGCGATAC-1           8633.0            490.0       5.675895
# BGCV15_TTTGTCACAAGCCATT-1           5315.0            103.0       1.937912
# BGCV15_TTTGTCATCGAATGGG-1           4399.0            126.0       2.864287
#
#                              full_clustering initial_clustering  Resample  \
# covid_index
# AAACCTGAGACCACGA-newcastle65       CD4.Naive                CD4   Initial
# AAACCTGAGATGTCGG-newcastle65         NK_16hi            NK_16hi   Initial
# AAACCTGAGGCGATAC-newcastle65       CD4.Naive               Treg   Initial
# AAACCTGAGTACACCT-newcastle65         NK_16hi            NK_16hi   Initial
# AAACCTGAGTGAATTG-newcastle65          CD8.EM                CD4   Initial
# ...                                      ...                ...       ...
# BGCV15_TTTGGTTGTTGGGACA-1             CD4.CM                CD4  Resample
# BGCV15_TTTGGTTTCAAGATCC-1            NK_16hi            NK_16hi   Initial
# BGCV15_TTTGTCAAGGCGATAC-1             CD4.CM                CD4  Resample
# BGCV15_TTTGTCACAAGCCATT-1            NK_16hi            NK_16hi   Initial
# BGCV15_TTTGTCATCGAATGGG-1            NK_16hi            NK_16hi  Resample
#
#                              Collection_Day  ... latent16_weighted  latent17  \
# covid_index                                  ...
# AAACCTGAGACCACGA-newcastle65             D0  ...         -0.001785  1.468550
# AAACCTGAGATGTCGG-newcastle65             D0  ...         -0.000797  0.931305
# AAACCTGAGGCGATAC-newcastle65             D0  ...         -0.004393  0.311716
# AAACCTGAGTACACCT-newcastle65             D0  ...         -0.000654  0.956112
# AAACCTGAGTGAATTG-newcastle65             D0  ...          0.000130  3.312108
# ...                                     ...  ...               ...       ...
# BGCV15_TTTGGTTGTTGGGACA-1               D28  ...         -0.003533 -0.744805
# BGCV15_TTTGGTTTCAAGATCC-1                D0  ...         -0.007589 -1.024590
# BGCV15_TTTGTCAAGGCGATAC-1               D28  ...         -0.000226 -2.361145
# BGCV15_TTTGTCACAAGCCATT-1                D0  ...          0.002946 -1.007869
# BGCV15_TTTGTCATCGAATGGG-1               D28  ...         -0.004884 -3.017950
#
#                              latent17_weighted  latent18 latent18_weighted  \
# covid_index
# AAACCTGAGACCACGA-newcastle65          0.003737 -0.129735         -0.000330
# AAACCTGAGATGTCGG-newcastle65          0.012409 -1.097414         -0.014622
# AAACCTGAGGCGATAC-newcastle65          0.001710 -0.710029         -0.003896
# AAACCTGAGTACACCT-newcastle65          0.007059 -1.630411         -0.012037
# AAACCTGAGTGAATTG-newcastle65          0.015071 -0.890888         -0.004054
# ...                                        ...       ...               ...
# BGCV15_TTTGGTTGTTGGGACA-1            -0.005636 -0.210822         -0.001595
# BGCV15_TTTGGTTTCAAGATCC-1            -0.011589 -1.062178         -0.012014
# BGCV15_TTTGTCAAGGCGATAC-1            -0.010059 -1.279952         -0.005453
# BGCV15_TTTGTCACAAGCCATT-1            -0.007209 -1.200402         -0.008586
# BGCV15_TTTGTCATCGAATGGG-1            -0.049007 -0.823149         -0.013367
#
#                               latent19 latent19_weighted top_cells_Healthy  \
# covid_index
# AAACCTGAGACCACGA-newcastle65 -0.651870         -0.001659             False
# AAACCTGAGATGTCGG-newcastle65 -0.928879         -0.012377             False
# AAACCTGAGGCGATAC-newcastle65 -0.560013         -0.003073             False
# AAACCTGAGTACACCT-newcastle65 -0.962009         -0.007102             False
# AAACCTGAGTGAATTG-newcastle65 -0.917382         -0.004174             False
# ...                                ...               ...               ...
# BGCV15_TTTGGTTGTTGGGACA-1    -0.517429         -0.003915             False
# BGCV15_TTTGGTTTCAAGATCC-1    -0.774521         -0.008761             False
# BGCV15_TTTGTCAAGGCGATAC-1    -0.739373         -0.003150             False
# BGCV15_TTTGTCACAAGCCATT-1    -1.300979         -0.009305             False
# BGCV15_TTTGTCATCGAATGGG-1    -0.837704         -0.013603             False
#
#                              top_cells_Mild top_cells_Severe
# covid_index
# AAACCTGAGACCACGA-newcastle65          False            False
# AAACCTGAGATGTCGG-newcastle65          False            False
# AAACCTGAGGCGATAC-newcastle65          False            False
# AAACCTGAGTACACCT-newcastle65          False            False
# AAACCTGAGTGAATTG-newcastle65          False            False
# ...                                     ...              ...
# BGCV15_TTTGGTTGTTGGGACA-1             False            False
# BGCV15_TTTGGTTTCAAGATCC-1             False            False
# BGCV15_TTTGTCAAGGCGATAC-1             False            False
# BGCV15_TTTGTCACAAGCCATT-1             False            False
# BGCV15_TTTGTCATCGAATGGG-1             False            False
#
# [256051 rows x 80 columns]

# %%
tmp = sc.AnnData(adata.obsm['latent'])
tmp.obs = adata.obs
tmp
# Out:
# AnnData object with n_obs × n_vars = 256051 × 20
#     obs: 'sample_id', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'full_clustering', 'initial_clustering', 'Resample', 'Collection_Day', 'Sex', 'Age_interval', 'Swab_result', 'Status', 'Smoker', 'Status_on_day_collection', 'Status_on_day_collection_summary', 'Days_from_onset', 'Site', 'time_after_LPS', 'Worst_Clinical_Status', 'Outcome', 'patient_id', 'split0', 'split1', 'split2', 'split3', 'split4', 'group', 'size_factors', '_scvi_batch', 'cell_attn_0', 'cell_attn_1', 'cell_attn_2', 'cell_attn_3', 'cell_attn_4', 'cell_attn', 'latent0', 'latent0_weighted', 'latent1', 'latent1_weighted', 'latent2', 'latent2_weighted', 'latent3', 'latent3_weighted', 'latent4', 'latent4_weighted', 'latent5', 'latent5_weighted', 'latent6', 'latent6_weighted', 'latent7', 'latent7_weighted', 'latent8', 'latent8_weighted', 'latent9', 'latent9_weighted', 'latent10', 'latent10_weighted', 'latent11', 'latent11_weighted', 'latent12', 'latent12_weighted', 'latent13', 'latent13_weighted', 'latent14', 'latent14_weighted', 'latent15', 'latent15_weighted', 'latent16', 'latent16_weighted', 'latent17', 'latent17_weighted', 'latent18', 'latent18_weighted', 'latent19', 'latent19_weighted', 'top_cells_Healthy', 'top_cells_Mild', 'top_cells_Severe'

# %%
for i in range(tmp.X.shape[1]):
    tmp.obs[f'latent{i}'] = tmp.X[:, i].copy()
    tmp.obs[f'latent{i}_weighted'] = tmp.obs[f'latent{i}'] * tmp.obs['cell_attn']
tmp.obs[['latent0', 'latent0_weighted', 'cell_attn']]
# Out:
#                                latent0  latent0_weighted  cell_attn
# covid_index
# AAACCTGAGACCACGA-newcastle65 -0.170344         -0.000433   0.002545
# AAACCTGAGATGTCGG-newcastle65 -1.007411         -0.013423   0.013324
# AAACCTGAGGCGATAC-newcastle65 -0.251497         -0.001380   0.005487
# AAACCTGAGTACACCT-newcastle65 -0.701973         -0.005182   0.007383
# AAACCTGAGTGAATTG-newcastle65 -0.109289         -0.000497   0.004550
# ...                                ...               ...        ...
# BGCV15_TTTGGTTGTTGGGACA-1     0.413836          0.003132   0.007567
# BGCV15_TTTGGTTTCAAGATCC-1    -0.254439         -0.002878   0.011311
# BGCV15_TTTGTCAAGGCGATAC-1    -0.605825         -0.002581   0.004260
# BGCV15_TTTGTCACAAGCCATT-1    -1.069658         -0.007651   0.007153
# BGCV15_TTTGTCATCGAATGGG-1    -0.136686         -0.002220   0.016239
#
# [256051 rows x 3 columns]

# %%
df = tmp.obs[[f'latent{i}' for i in range(tmp.X.shape[1])] + ['patient_id']].groupby('patient_id').agg('mean')
df = df.join(tmp.obs[['patient_id', 'Status_on_day_collection_summary', 'Site']].groupby('patient_id').agg('first'))
df[:3]
# Out:
#              latent0   latent1   latent2   latent3   latent4   latent5  \
# patient_id
# AP1         0.344548 -0.150528  0.306088 -0.187310  0.218147 -0.077847
# AP4         0.165106 -0.236559  0.614609 -0.148086 -0.038765 -0.132805
# AP5         0.413475 -0.663631 -0.038010 -0.501842 -0.212037 -0.038159
#
#              latent6   latent7   latent8   latent9  ...  latent12  latent13  \
# patient_id                                          ...
# AP1         0.230981 -0.208586 -0.254200  0.043318  ...  0.047392 -0.403155
# AP4         0.151039 -0.324218 -0.330311 -0.025014  ... -0.030480 -0.076111
# AP5        -0.037974 -0.089472 -0.399102 -0.011391  ... -0.117136 -0.107880
#
#             latent14  latent15  latent16  latent17  latent18  latent19  \
# patient_id
# AP1        -0.187793 -0.164077 -0.282662  0.319426 -0.171868 -0.065580
# AP4        -0.179940 -0.233890 -0.197369  0.096934 -0.378309 -0.326807
# AP5        -0.293442 -0.190262  0.079365 -0.133489  0.218204 -0.356163
#
#             Status_on_day_collection_summary    Site
# patient_id
# AP1                                   Severe  Sanger
# AP4                                     Mild  Sanger
# AP5                                   Severe  Sanger
#
# [3 rows x 22 columns]

# %%
pb = sc.AnnData(df.drop(['Status_on_day_collection_summary', 'Site'], axis=1).values)
pb.obs = df[['Status_on_day_collection_summary', 'Site']]
pb
# Out:
# AnnData object with n_obs × n_vars = 49 × 20
#     obs: 'Status_on_day_collection_summary', 'Site'

# %%
X = df.drop(['Status_on_day_collection_summary', 'Site'], axis=1).values
y = df[['Status_on_day_collection_summary']].values.ravel()

# %%
loo = LeaveOneOut()

# %%
mean_train_accuracies = {}
mean_test_accuracies = {}
for k in [3, 5, 7, 9]:
    train_accuracies = []
    test_accuracies = []
    for i, (train_index, test_index) in enumerate(loo.split(X)):
        knn = KNeighborsClassifier(n_neighbors = k)
        X_train = X[train_index]
        y_train = y[train_index]
        X_test = X[test_index]
        y_test = y[test_index]
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        knn.fit(X_train, y_train)
        y_train_predict = knn.predict(X_train)
        y_test_predict = knn.predict(X_test)
        train_accuracies.append(np.mean(y_train_predict == y_train))
        test_accuracies.append(np.mean(y_test_predict == y_test))
    mean_train_accuracies[k] = train_accuracies
    mean_test_accuracies[k] = test_accuracies

# %%
for k in [3, 5, 7, 9]:
    print(f'k = {k}:')
    print(np.mean(np.array(mean_train_accuracies[k])))
    print(np.mean(np.array(mean_test_accuracies[k])))
# Out:
# k = 3:
# 0.7976190476190476
# 0.6122448979591837
# k = 5:
# 0.7351190476190476
# 0.6326530612244898
# k = 7:
# 0.6968537414965985
# 0.6530612244897959
# k = 9:
# 0.71343537414966
# 0.6122448979591837

# %%
sc.pp.neighbors(pb)

# %%
sc.tl.umap(pb)

# %%
sc.pl.umap(
    pb,
    color=['Site'],
    frameon=False,
    title='',
    legend_loc=None,
    #palette=['#EAE280', '#E59A88', '#B62A6F'],
    #save='_pbmc_patient_repr_site.svg'
)

# %%
sc.pl.umap(
    pb,
    color=['Status_on_day_collection_summary'],
    frameon=False,
    title='',
    legend_loc=None,
    palette=['#EAE280', '#E59A88', '#B62A6F'],
    #save='_pbmc_patient_repr.svg'
)

# %%
df = tmp.obs[[f'latent{i}_weighted' for i in range(tmp.X.shape[1])] + ['patient_id']].groupby('patient_id').agg('sum')
df = df.join(tmp.obs[['patient_id', 'Status_on_day_collection_summary', 'Site']].groupby('patient_id').agg('first'))
df[:3]
# Out:
#             latent0_weighted  latent1_weighted  latent2_weighted  \
# patient_id
# AP1                16.669622         -3.335166        -27.513748
# AP4                27.360037        -16.184084        -30.098608
# AP5                22.570795        -37.518116        -35.845566
#
#             latent3_weighted  latent4_weighted  latent5_weighted  \
# patient_id
# AP1                -3.019145         10.422900         -7.620132
# AP4                -1.617636         -0.610341         -7.006254
# AP5               -26.722336         -5.989817        -12.149614
#
#             latent6_weighted  latent7_weighted  latent8_weighted  \
# patient_id
# AP1                17.445404         -2.806888        -11.163363
# AP4                33.591419        -19.937073        -25.516838
# AP5                -5.203456         -9.177300        -23.491253
#
#             latent9_weighted  ...  latent12_weighted  latent13_weighted  \
# patient_id                    ...
# AP1                 1.975628  ...          -7.320600         -14.922719
# AP4                -1.673222  ...         -29.212269          -6.236036
# AP5                -2.336450  ...         -24.563059         -23.518967
#
#             latent14_weighted  latent15_weighted  latent16_weighted  \
# patient_id
# AP1                 -8.002012         -12.904438         -40.140285
# AP4                 -3.049368         -34.963337         -85.964401
# AP5                -23.906406         -14.436861          -4.669443
#
#             latent17_weighted  latent18_weighted  latent19_weighted  \
# patient_id
# AP1                 10.260696         -16.989588          11.027155
# AP4                 17.317791         -50.163876         -12.052011
# AP5                -17.391506          39.080727          10.473234
#
#             Status_on_day_collection_summary    Site
# patient_id
# AP1                                   Severe  Sanger
# AP4                                     Mild  Sanger
# AP5                                   Severe  Sanger
#
# [3 rows x 22 columns]

# %%
pb = sc.AnnData(df.drop(['Status_on_day_collection_summary', 'Site'], axis=1).values)
pb.obs = df[['Status_on_day_collection_summary', 'Site']]
pb
# Out:
# AnnData object with n_obs × n_vars = 49 × 20
#     obs: 'Status_on_day_collection_summary', 'Site'

# %%
X = df.drop(['Status_on_day_collection_summary', 'Site'], axis=1).values
y = df[['Status_on_day_collection_summary']].values.ravel()

# %%
loo = LeaveOneOut()

# %%
attn_train_accuracies = {}
attn_test_accuracies = {}
for k in [3, 5, 7, 9]:
    train_accuracies = []
    test_accuracies = []
    for i, (train_index, test_index) in enumerate(loo.split(X)):
        knn = KNeighborsClassifier(n_neighbors = k)
        X_train = X[train_index]
        y_train = y[train_index]
        X_test = X[test_index]
        y_test = y[test_index]
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        knn.fit(X_train, y_train)
        y_train_predict = knn.predict(X_train)
        y_test_predict = knn.predict(X_test)
        train_accuracies.append(np.mean(y_train_predict == y_train))
        test_accuracies.append(np.mean(y_test_predict == y_test))
    attn_train_accuracies[k] = train_accuracies
    attn_test_accuracies[k] = test_accuracies

# %%
for k in [3, 5, 7, 9]:
    print(f'k = {k}:')
    print(np.mean(np.array(attn_train_accuracies[k])))
    print(np.mean(np.array(attn_test_accuracies[k])))
# Out:
# k = 3:
# 0.8358843537414966
# 0.673469387755102
# k = 5:
# 0.8265306122448981
# 0.6938775510204082
# k = 7:
# 0.7568027210884354
# 0.673469387755102
# k = 9:
# 0.7079081632653063
# 0.6530612244897959

# %%
sc.pp.neighbors(pb)

# %%
sc.tl.umap(pb)

# %%
sc.pl.umap(
    pb,
    color=['Site'],
    frameon=False,
    title='',
    legend_loc=None,
    #palette=['#EAE280', '#E59A88', '#B62A6F'],
    #save='_pbmc_patient_repr_weighted_site.svg'
)

# %%
sc.pl.umap(
    pb,
    color=['Status_on_day_collection_summary'],
    frameon=False,
    title='',
    legend_loc=None,
    palette=['#EAE280', '#E59A88', '#B62A6F'],
    #save='_pbmc_patient_repr_weighted.svg'
)

# %%
df1 = pd.DataFrame(attn_test_accuracies)
df2 = pd.DataFrame(mean_test_accuracies)

# %%
sc.set_figure_params(vector_friendly=True, figsize=(6,4))
plt.plot(df1.mean().index.astype(str).values, df1.mean().values, label='Attention')
plt.plot(df2.mean().index.astype(str).values, df2.mean().values, label='Mean')
plt.xlabel('k in kNN clasifier')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('figures/mil_knn_classifier.svg', bbox_inches='tight')
